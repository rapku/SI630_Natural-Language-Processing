# %%
import pandas as pd
import json
# %matplotlib inline

# %%
context = pd.DataFrame({'NLL+-2':pd.read_json('NLLpm2.json', typ='series'), 
                       'NLL -4': pd.read_json('NLLneg4.json', typ='series'),
                       'NLL +4': pd.read_json('NLLpos4.json', typ='series')})

context
# Out:
#             NLL +4        NLL -4        NLL+-2
# 0         0.000000      0.000000      0.000000
# 1     67506.605371  67527.681530  67286.516961
# 2     67342.691005  67338.263100  67166.072254
# 3     66812.819266  66648.276257  66620.931855
# 4     66021.770405  65866.957858  65456.816471
# 5     64811.089459  64837.871661  64371.534185
# 6     64013.594885  63866.712405      0.000000
# 7     63191.953428  62810.668094  63436.469046
# 8     62145.593210  62287.258904  62531.585013
# 9     61816.964479  61803.564869  61890.145420
# 10    61493.791201  61322.258586  61420.139752
# 11        0.000000  60804.399747  60791.249462
# 12    60986.600580  60442.059413  60406.328966
# 13    60558.890071  59684.499919  59895.342568
# 14    59820.562162  59234.766286  58895.873384
# 15    59547.677740  58907.011055  58806.587300
# 16    59253.861493  58696.695255  58324.569504
# 17    58629.351863      0.000000  57909.751110
# 18    59077.338712  58867.628263  58381.420472
# ...

# %%
a = context['NLL+-2'].plot(figsize=(12, 12))
a.set(xlabel = '10,000 iterations', ylabel = 'Negative Log Likelihood')
# Out:
# [Text(0,0.5,'Negative Log Likelihood'), Text(0.5,0,'10,000 iterations')]

# %%
b = context['NLL -4'].plot(figsize=(12, 12))
b.set(xlabel = '10,000 iterations', ylabel = 'Negative Log Likelihood')
# Out:
# [Text(0,0.5,'Negative Log Likelihood'), Text(0.5,0,'10,000 iterations')]

# %%
c = context['NLL +4'].plot(figsize=(12, 12))
c.set(xlabel = '10,000 iterations', ylabel = 'Negative Log Likelihood')
# Out:
# [Text(0,0.5,'Negative Log Likelihood'), Text(0.5,0,'10,000 iterations')]

# %%
c = context.plot(figsize=(12, 12))
c.set(xlabel = '10,000 iterations', ylabel = 'Negative Log Likelihood')
# Out:
# [Text(0,0.5,'Negative Log Likelihood'), Text(0.5,0,'10,000 iterations')]
